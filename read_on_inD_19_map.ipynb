# %%
import pandas as pd
tracks_pd = pd.read_csv("/DATA1/rzhou/ika/inD/data/19_tracks.csv",low_memory=False)
selected_data = tracks_pd.iloc[:100, [2, 4, 5]].values
# Out:
# Failed to start the Kernel.
#
# ImportError: /home/rzhou/miniconda3/lib/python3.11/lib-dynload/_sqlite3.cpython-311-x86_64-linux-gnu.so: undefined symbol: sqlite3_deserialize.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(selected_data.shape)
print(selected_data)
# Out:
# Failed to start the Kernel.
#
# ImportError: /home/rzhou/miniconda3/lib/python3.11/lib-dynload/_sqlite3.cpython-311-x86_64-linux-gnu.so: undefined symbol: sqlite3_deserialize.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pickle
import numpy as np
# 以二进制读取模式打开 pickle 文件
with open("/home/rzhou/Projects/timegan-pytorch/output/inD_18-29_single_car_Epoch5000_noZfilter_minGLoss_1000periodic/rescaled_fake_data.pickle", "rb") as file:
    data = pickle.load(file)
#print(data)
print(data.shape)
# 给定一个形状为 (2787, 100, 2) 的数组，我们可以使用 numpy 来随机选择一行。
# 我将使用 numpy 的随机选择功能来实现这一点。

# 随机选择一行
# selected_row_index = np.random.randint(data.shape[0])
# selected_data = data[selected_row_index, :, :]
selected_data=data[-10]

#print(selected_row_index)
print(selected_data)
print(selected_data.shape)
# Out:
# Failed to start the Kernel.
#
# ImportError: /home/rzhou/miniconda3/lib/python3.11/lib-dynload/_sqlite3.cpython-311-x86_64-linux-gnu.so: undefined symbol: sqlite3_deserialize.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#读取single case

import numpy as np
import matplotlib.pyplot as plt

# 假设 selected_data 是一个形状为 (100, 3) 的数组，此处随机生成用于演示

# 载入背景图片，此处使用一个假设的路径，你需要替换为实际的文件路径
bg_image_path = '/DATA1/rzhou/ika/inD/data/19_background.png'  # 假设的背景图路径

# 创建图形和轴
fig, ax = plt.subplots(figsize=(11.7, 7.8))

# 设置坐标轴的范围
ax.set_xlim(0, 80)
ax.set_ylim(-60, 0)

# 绘制背景图：这需要一个真实的背景图文件
# 使用extent来匹配背景图的实际坐标位置
bg_img = plt.imread(bg_image_path)
ax.imshow(bg_img, extent=[0, 117, -78, 0])

# 绘制轨迹
x = selected_data[:, 0]
y = selected_data[:, 1]
ax.plot(x, y, marker='o', color='red')  # 使用红色标记点的轨迹


# colors = ['red', 'green', 'blue', 'orange', 'purple']  # 为每个轨迹指定颜色
# for i in range(5):
#     # 提取每个点的x和y坐标
#     x = selected_data[:, 1 + i*2]
#     y = selected_data[:, 2 + i*2]
#     # 绘制轨迹
#     ax.plot(x, y, marker='o', linestyle='-', color=colors[i], label=f'Point {i+1}')

# 添加图例
ax.legend()

plt.show()

# %%
import pandas as pd
tracks_np = pd.read_csv("/DATA1/rzhou/ika/multi_testcases/inD_multi_18-29.csv",low_memory=False).values
selected_data = tracks_np[10000:10100]

# %%
import pickle
import numpy as np
# 以二进制读取模式打开 pickle 文件
with open("/home/rzhou/Projects/timegan-pytorch/output/inD_18-29_multi_Epoch10000_withoutZfilter_min_G_Loss_1000periodic/rescaled_fake_data.pickle", "rb") as file:
    data = pickle.load(file)
#print(data)
print(data.shape)
# 给定一个形状为 (2787, 100, 2) 的数组，我们可以使用 numpy 来随机选择一行。
# 我将使用 numpy 的随机选择功能来实现这一点。

# 随机选择一行
# selected_row_index = np.random.randint(data.shape[0])
# selected_data = data[selected_row_index, :, :]
selected_data=data[-5]

#print(selected_row_index)
print(selected_data)
print(selected_data.shape)
# Out:
# (1429, 100, 10)
# [[ 70.57199   -39.372368    5.0505376 -25.157145    6.754248  -27.841368
#    58.759335   -6.7378845  88.476074  -31.114754 ]
#  [ 59.12996   -23.858553   48.4402    -18.124733   43.326305  -27.387976
#    64.14233   -19.598984   59.086014  -25.056978 ]
#  [ 63.61931   -23.33154    49.760033  -15.839607   52.982544  -25.39125
#    55.529377  -21.041702   59.160507  -26.335497 ]
#  [ 61.45661   -25.169786   53.696503  -18.242882   55.253563  -22.530678
#    53.32224   -24.25548    49.892437  -28.569653 ]
#  [ 55.732662  -25.525053   55.072914  -19.519825   61.253235  -19.919395
#    50.515827  -26.261065   45.692535  -29.568129 ]
#  [ 54.407246  -26.639278   56.52262   -23.648314   57.585476  -19.511578
#    53.42075   -26.756794   40.528637  -29.920244 ]
#  [ 48.62972   -24.439474   53.16677   -24.652592   65.7989    -19.019657
#    52.6679    -28.00002    39.280052  -31.193056 ]
#  [ 48.199566  -23.998415   55.32692   -25.927048   55.00693   -23.616488
#    55.867172  -25.766659   36.508476  -30.311872 ]
#  [ 43.675602  -21.34359    46.2871    -24.756466   68.10994   -23.888138
#    51.153038  -28.216417   39.907066  -31.37666  ]
#  [ 45.590923  -21.478851   57.73259   -24.28113    54.71429   -29.440113
#    60.288177  -23.64295    43.086643  -27.547285 ]
#  [ 50.414     -22.124928   45.3348    -23.488098   63.704357  -25.010803
#    48.84562   -30.192047   42.11851   -30.884192 ]
#  [ 58.006786  -23.226635   63.296898  -25.122334   50.5934    -28.32288
#    63.482395  -22.686386   44.87038   -26.38704  ]
#  [ 55.920547  -23.812824   41.009438  -26.999428   63.782917  -23.990835
#    51.024967  -30.048246   39.638775  -31.005661 ]
#  [ 58.924637  -24.213404   62.190094  -26.287476   49.653103  -27.69886
#    64.72696   -21.528286   46.47145   -26.413004 ]
#  [ 55.249443  -24.340601   37.642838  -27.798788   63.20848   -23.71086
#    52.99558   -29.575722   39.16369   -30.94631  ]
#  [ 58.392513  -24.692743   61.560204  -26.321108   48.649303  -26.721167
#    66.524506  -20.405766   46.477524  -25.63989  ]
#  [ 53.734043  -24.770094   35.667465  -28.11013    62.421673  -22.969254
#    54.901356  -29.083641   37.485264  -30.268639 ]
#  [ 57.42099   -25.252375   60.59639   -26.270905   47.94587   -25.664967
#    67.823975  -19.705112   45.62006   -25.24765  ]
#  [ 51.925205  -25.122593   34.27957   -28.34556    62.05114   -22.31016
#    53.11823   -26.172209   40.45074   -25.497952 ]
#  [ 41.58953   -24.236837   58.24804   -25.69638    50.455975  -25.02921
#    65.057556  -18.548878   48.059834  -21.897942 ]
#  [ 36.314552  -24.114536   37.83912   -24.330229   63.261597  -20.452747
#    52.59764   -26.257017   41.560394  -25.509398 ]
#  [ 41.78092   -24.02794    58.132584  -25.762005   50.40212   -25.149498
#    64.72726   -18.553764   47.905277  -21.753529 ]
#  [ 36.11345   -23.915955   38.44982   -24.544373   63.04532   -20.610928
#    52.654682  -26.269957   41.739952  -25.46656  ]
#  [ 41.952816  -23.823236   58.487     -25.92427    50.349262  -25.357283
#    64.6821    -18.71177    48.635788  -21.884401 ]
#  [ 36.61045   -23.757643   38.498856  -24.433182   63.167732  -20.763111
#    52.35874   -26.322193   42.503975  -25.501    ]
#  [ 42.17742   -23.673645   58.443848  -26.012815   50.230034  -25.520016
#    64.47516   -18.726963   48.599094  -21.820711 ]
#  [ 36.73478   -23.567478   38.676758  -24.541958   63.177425  -20.720993
#    52.05625   -26.434553   42.742462  -25.45575  ]
#  [ 42.377483  -23.497849   58.586906  -26.038342   50.253857  -25.558159
#    64.32215   -18.829014   48.945793  -21.79763  ]
#  [ 36.658897  -23.440468   39.55062   -24.58493    62.786793  -20.82623
#    52.007225  -26.371191   43.41611   -25.382856 ]
#  [ 42.571358  -23.240135   58.76332   -26.280685   49.797073  -25.86789
#    63.81282   -19.110748   49.461224  -21.946074 ]
#  [ 37.246902  -23.130995   39.999912  -24.455822   62.892338  -21.030708
#    51.34721   -26.494558   44.47136   -25.392801 ]
#  [ 42.682354  -22.952333   58.84973   -26.436563   49.853344  -26.057468
#    63.464863  -19.222752   49.508736  -21.972694 ]]
# (100, 10)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 假设 selected_data 是一个形状为 (100, 3) 的数组，此处随机生成用于演示

# 载入背景图片，此处使用一个假设的路径，你需要替换为实际的文件路径
bg_image_path = '/DATA1/rzhou/ika/inD/data/19_background.png'  # 假设的背景图路径

# 创建图形和轴
fig, ax = plt.subplots(figsize=(11.7, 7.8))

# 设置坐标轴的范围
ax.set_xlim(0, 80)
ax.set_ylim(-60, 0)

# 绘制背景图：这需要一个真实的背景图文件
# 使用extent来匹配背景图的实际坐标位置
bg_img = plt.imread(bg_image_path)
ax.imshow(bg_img, extent=[0, 117, -78, 0])

# 绘制轨迹
# x = selected_data[:, 1]
# y = selected_data[:, 2]
# ax.plot(x, y, marker='o', color='red')  # 使用红色标记点的轨迹


colors = ['red', 'green', 'blue', 'orange', 'purple']  # 为每个轨迹指定颜色
for i in range(5):
    # 提取每个点的x和y坐标
    x = selected_data[:, + i*2]
    y = selected_data[:, 1 + i*2]
    # 绘制轨迹
    ax.plot(x, y, marker='o', linestyle='-', color=colors[i], label=f'Point {i+1}')

# 添加图例
ax.legend()

plt.show()
