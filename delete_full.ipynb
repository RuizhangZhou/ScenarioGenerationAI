# %%
import numpy as np
import pandas as pd

# %%
cases_np = pd.read_csv('/home/rzhou/Projects/generating-models-for-test-cases/scenariogenerationai/testcases/inD/cases/00/001_testcases.csv').values

# %%
cases_np[-1]
# Out:
# array([  18.     , 1371.     ,   57.30352,  -95.54519])

# %%
#coding:utf-8
import os

def delete(i):
    filePath = "/home/rzhou/Projects/generating-models-for-test-cases/scenariogenerationai/testcases/inD/cases/%(i)02d" %{
        'i':i
    }
    name = os.listdir(filePath)
    #打印所指定文件夹内的所包含 的文件数  文件名
    print(len(name))
    print(name)
    for n in name:
        path="/home/rzhou/Projects/generating-models-for-test-cases/scenariogenerationai/testcases/inD/cases/%(i)02d/%(n)s" %{
        'i':i, 'n':n}
        print(path)
        #！！！判断如果文件名包含anzw 就删除
        if 'full' in n:
            os.remove(path)

# %%
for i in range(33):
    delete(i)
# Out:
# 32
# ['002_testcases.csv', '014_testcases.csv_full.csv', '009_testcases.csv_full.csv', '012_testcases.csv_full.csv', '013_testcases.csv', '004_testcases.csv', '006_testcases.csv', '001_testcases.csv', '006_testcases.csv_full.csv', '010_testcases.csv_full.csv', '014_testcases.csv', '005_testcases.csv', '011_testcases.csv_full.csv', '011_testcases.csv', '015_testcases.csv_full.csv', '008_testcases.csv_full.csv', '004_testcases.csv_full.csv', '007_testcases.csv', '001_testcases.csv_full.csv', '005_testcases.csv_full.csv', '003_testcases.csv', '013_testcases.csv_full.csv', '003_testcases.csv_full.csv', '007_testcases.csv_full.csv', '016_testcases.csv_full.csv', '009_testcases.csv', '002_testcases.csv_full.csv', '015_testcases.csv', '012_testcases.csv', '010_testcases.csv', '016_testcases.csv', '008_testcases.csv']
# /home/rzhou/Projects/generating-models-for-test-cases/scenariogenerationai/testcases/inD/cases/00/002_testcases.csv
# ...
